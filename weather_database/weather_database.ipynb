# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

from operator import itemgetter

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #city_description = list(map(itemgetter("description"), city_weather["weather"]))
        city_description = city_weather['weather'][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Current Description": ( ", ".join(city_description))
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san juan
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | launceston
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | mount isa
# Processing Record 6 of Set 1 | qostanay
# Processing Record 7 of Set 1 | maniitsoq
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | luanda
# Processing Record 10 of Set 1 | sabha
# Processing Record 11 of Set 1 | phangnga
# Processing Record 12 of Set 1 | galesong
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | anadyr
# Processing Record 17 of Set 1 | vanavara
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | vila velha
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | burnie
# Processing Record 30 of Set 1 | aleksandrovskoye
# Processing Record 31 of Set 1 | tabou
# Processing Record 32 of Set 1 | shimanovsk
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | eureka
# Processing Record 36 of Set 1 | north bend
# Processing Record 37 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | caravelas
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | carbonia
# Processing Record 43 of Set 1 | sherlovaya gora
# Processing Record 44 of Set 1 | riverton
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | saint-georges
# Processing Record 47 of Set 1 | catamarca
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | yeletskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | svetlogorsk
# Processing Record 6 of Set 2 | yantal
# Processing Record 7 of Set 2 | deputatskiy
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | labuan
# Processing Record 11 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | vestmanna
# Processing Record 14 of Set 2 | puerto escondido
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | mlonggo
# Processing Record 17 of Set 2 | evensk
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | surin
# Processing Record 20 of Set 2 | bayan
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | salalah
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | port-gentil
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | fallon
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | scarborough
# Processing Record 30 of Set 2 | rocha
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | gorom-gorom
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | abu zabad
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | faya
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | kieta
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | sorland
# Processing Record 44 of Set 2 | erzurum
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | haines junction
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | havre-saint-pierre
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | nalut
# Processing Record 1 of Set 3 | alice springs
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | luau
# Processing Record 4 of Set 3 | tonder
# Processing Record 5 of Set 3 | saryozek
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | kochevo
# Processing Record 8 of Set 3 | beloha
# Processing Record 9 of Set 3 | san luis
# Processing Record 10 of Set 3 | coihaique
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | garut
# Processing Record 13 of Set 3 | mecca
# Processing Record 14 of Set 3 | spantov
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | goderich
# Processing Record 17 of Set 3 | tilichiki
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | oktyabrskiy
# Processing Record 20 of Set 3 | port blair
# Processing Record 21 of Set 3 | biak
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | muscat
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | zhanaozen
# Processing Record 30 of Set 3 | sola
# Processing Record 31 of Set 3 | yarada
# Processing Record 32 of Set 3 | praia
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | buchen
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | strelca
# City not found. Skipping...
# Processing Record 39 of Set 3 | oyem
# Processing Record 40 of Set 3 | langarud
# Processing Record 41 of Set 3 | qiqihar
# Processing Record 42 of Set 3 | egersund
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | coquimbo
# Processing Record 45 of Set 3 | tessalit
# Processing Record 46 of Set 3 | bonthe
# Processing Record 47 of Set 3 | saint-joseph
# Processing Record 48 of Set 3 | maragogi
# Processing Record 49 of Set 3 | westport
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | gallup
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | taltal
# Processing Record 4 of Set 4 | adrar
# Processing Record 5 of Set 4 | cooma
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | nipawin
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | tyup
# Processing Record 12 of Set 4 | meulaboh
# Processing Record 13 of Set 4 | tromso
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | nioro
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | chokurdakh
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | bourail
# Processing Record 20 of Set 4 | castro
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | canto do buriti
# Processing Record 23 of Set 4 | linhares
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 26 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 4 | genhe
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | debre birhan
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | thompson
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | vanderhoof
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | banjar
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | lasa
# Processing Record 40 of Set 4 | antalaha
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 4 | bubaque
# Processing Record 44 of Set 4 | clinton
# Processing Record 45 of Set 4 | inhambane
# Processing Record 46 of Set 4 | acarau
# Processing Record 47 of Set 4 | broome
# Processing Record 48 of Set 4 | coos bay
# Processing Record 49 of Set 4 | broken hill
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | pacific grove
# Processing Record 3 of Set 5 | mayumba
# Processing Record 4 of Set 5 | porto novo
# Processing Record 5 of Set 5 | yar-sale
# Processing Record 6 of Set 5 | monte azul
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | voznesenskoye
# Processing Record 9 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 5 | vozhega
# Processing Record 11 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | dukat
# Processing Record 14 of Set 5 | fairbanks
# Processing Record 15 of Set 5 | bhum
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | banda aceh
# Processing Record 18 of Set 5 | barrow
# Processing Record 19 of Set 5 | razdolnoye
# Processing Record 20 of Set 5 | katobu
# Processing Record 21 of Set 5 | senanga
# Processing Record 22 of Set 5 | nador
# Processing Record 23 of Set 5 | canton
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | coruripe
# Processing Record 26 of Set 5 | angoche
# Processing Record 27 of Set 5 | tanggul
# Processing Record 28 of Set 5 | juneau
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | mishan
# Processing Record 31 of Set 5 | la ronge
# Processing Record 32 of Set 5 | tsaratanana
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | la jagua del pilar
# Processing Record 35 of Set 5 | arlit
# Processing Record 36 of Set 5 | aurdal
# Processing Record 37 of Set 5 | hovd
# Processing Record 38 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 39 of Set 5 | denpasar
# Processing Record 40 of Set 5 | winslow
# Processing Record 41 of Set 5 | biggar
# Processing Record 42 of Set 5 | touros
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | yumen
# Processing Record 45 of Set 5 | vavatenina
# Processing Record 46 of Set 5 | arrecife
# Processing Record 47 of Set 5 | yzeure
# Processing Record 48 of Set 5 | yegros
# Processing Record 49 of Set 5 | mayo
# Processing Record 50 of Set 5 | moses lake
# Processing Record 1 of Set 6 | torbat-e jam
# Processing Record 2 of Set 6 | barpeta
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | tyssedal
# Processing Record 6 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 6 | urumqi
# Processing Record 8 of Set 6 | hilo
# Processing Record 9 of Set 6 | kavieng
# Processing Record 10 of Set 6 | quime
# Processing Record 11 of Set 6 | balrampur
# Processing Record 12 of Set 6 | mandalgovi
# Processing Record 13 of Set 6 | chake chake
# Processing Record 14 of Set 6 | nenjiang
# Processing Record 15 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 6 | pampierstad
# Processing Record 17 of Set 6 | kitui
# Processing Record 18 of Set 6 | rio grande
# Processing Record 19 of Set 6 | waipawa
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | illapel
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | matara
# Processing Record 24 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 25 of Set 6 | mugur-aksy
# Processing Record 26 of Set 6 | feijo
# Processing Record 27 of Set 6 | brenham
# Processing Record 28 of Set 6 | kloulklubed
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | portland
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | kaniama
# Processing Record 36 of Set 6 | bambanglipuro
# Processing Record 37 of Set 6 | yulara
# Processing Record 38 of Set 6 | corrente
# Processing Record 39 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 6 | srednekolymsk
# Processing Record 41 of Set 6 | sur
# Processing Record 42 of Set 6 | florianopolis
# Processing Record 43 of Set 6 | bereda
# Processing Record 44 of Set 6 | chumikan
# Processing Record 45 of Set 6 | los llanos de aridane
# Processing Record 46 of Set 6 | avera
# Processing Record 47 of Set 6 | port macquarie
# Processing Record 48 of Set 6 | makakilo city
# Processing Record 49 of Set 6 | luangwa
# Processing Record 50 of Set 6 | bukama
# Processing Record 1 of Set 7 | kismayo
# Processing Record 2 of Set 7 | kutum
# Processing Record 3 of Set 7 | edendale
# Processing Record 4 of Set 7 | okhotsk
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | bhavani
# Processing Record 7 of Set 7 | taybad
# Processing Record 8 of Set 7 | praya
# Processing Record 9 of Set 7 | luce
# Processing Record 10 of Set 7 | braslav
# City not found. Skipping...
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | madang
# Processing Record 13 of Set 7 | kupang
# Processing Record 14 of Set 7 | qaanaaq
# Processing Record 15 of Set 7 | kuching
# Processing Record 16 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 17 of Set 7 | millville
# Processing Record 18 of Set 7 | batticaloa
# Processing Record 19 of Set 7 | muzhi
# Processing Record 20 of Set 7 | anchorage
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | casma
# Processing Record 23 of Set 7 | norsup
# Processing Record 24 of Set 7 | erzin
# Processing Record 25 of Set 7 | mundra
# Processing Record 26 of Set 7 | namibe
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | palmas
# Processing Record 29 of Set 7 | kavaratti
# Processing Record 30 of Set 7 | san cristobal
# Processing Record 31 of Set 7 | egvekinot
# Processing Record 32 of Set 7 | marshall
# Processing Record 33 of Set 7 | rugby
# Processing Record 34 of Set 7 | thunder bay
# Processing Record 35 of Set 7 | sohag
# Processing Record 36 of Set 7 | acapulco
# Processing Record 37 of Set 7 | talara
# Processing Record 38 of Set 7 | maracacume
# Processing Record 39 of Set 7 | ichinohe
# Processing Record 40 of Set 7 | mareeba
# Processing Record 41 of Set 7 | mandera
# Processing Record 42 of Set 7 | shambu
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | gravdal
# Processing Record 45 of Set 7 | palmer
# Processing Record 46 of Set 7 | rawson
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | quatre cocos
# Processing Record 49 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 7 | nishihara
# Processing Record 1 of Set 8 | seoul
# Processing Record 2 of Set 8 | grand gaube
# Processing Record 3 of Set 8 | kindu
# Processing Record 4 of Set 8 | gawler
# Processing Record 5 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 6 of Set 8 | havoysund
# Processing Record 7 of Set 8 | corbelia
# Processing Record 8 of Set 8 | pitimbu
# Processing Record 9 of Set 8 | korampallam
# Processing Record 10 of Set 8 | zlobin
# Processing Record 11 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 8 | tres arroyos
# Processing Record 13 of Set 8 | zile
# Processing Record 14 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 8 | loukhi
# Processing Record 16 of Set 8 | agustin codazzi
# Processing Record 17 of Set 8 | les cayes
# Processing Record 18 of Set 8 | nogales
# Processing Record 19 of Set 8 | victoria
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | moussoro
# Processing Record 22 of Set 8 | verkhnevilyuysk
# Processing Record 23 of Set 8 | pella
# Processing Record 24 of Set 8 | urucara
# Processing Record 25 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 8 | nuevo casas grandes
# Processing Record 27 of Set 8 | freeport
# Processing Record 28 of Set 8 | comodoro rivadavia
# Processing Record 29 of Set 8 | fortuna
# Processing Record 30 of Set 8 | hasaki
# Processing Record 31 of Set 8 | lithakia
# Processing Record 32 of Set 8 | jumla
# Processing Record 33 of Set 8 | esso
# Processing Record 34 of Set 8 | groa
# Processing Record 35 of Set 8 | ponta do sol
# Processing Record 36 of Set 8 | naze
# Processing Record 37 of Set 8 | zapolyarnyy
# Processing Record 38 of Set 8 | asau
# Processing Record 39 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 8 | mehamn
# Processing Record 41 of Set 8 | baherden
# Processing Record 42 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 8 | gamba
# Processing Record 44 of Set 8 | mancheral
# Processing Record 45 of Set 8 | newcastleton
# Processing Record 46 of Set 8 | ola
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | dzaoudzi
# Processing Record 49 of Set 8 | bambous virieux
# Processing Record 50 of Set 8 | miri
# Processing Record 1 of Set 9 | san ramon
# Processing Record 2 of Set 9 | morondava
# Processing Record 3 of Set 9 | ginir
# Processing Record 4 of Set 9 | longkou
# Processing Record 5 of Set 9 | curuguaty
# Processing Record 6 of Set 9 | poum
# Processing Record 7 of Set 9 | figeac
# Processing Record 8 of Set 9 | codajas
# Processing Record 9 of Set 9 | vrangel
# Processing Record 10 of Set 9 | alamor
# Processing Record 11 of Set 9 | abadan
# Processing Record 12 of Set 9 | sao gabriel
# Processing Record 13 of Set 9 | yarmouth
# Processing Record 14 of Set 9 | ruzomberok
# Processing Record 15 of Set 9 | sebastian
# Processing Record 16 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 9 | leningradskiy
# Processing Record 18 of Set 9 | sept-iles
# Processing Record 19 of Set 9 | bida
# Processing Record 20 of Set 9 | khandagayty
# Processing Record 21 of Set 9 | dingle
# Processing Record 22 of Set 9 | kishtwar
# Processing Record 23 of Set 9 | ribeira grande
# Processing Record 24 of Set 9 | berlevag
# Processing Record 25 of Set 9 | kampot
# Processing Record 26 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 9 | karratha
# Processing Record 28 of Set 9 | takaka
# Processing Record 29 of Set 9 | robertsport
# Processing Record 30 of Set 9 | dubbo
# Processing Record 31 of Set 9 | badou
# Processing Record 32 of Set 9 | houma
# Processing Record 33 of Set 9 | hambantota
# Processing Record 34 of Set 9 | paamiut
# Processing Record 35 of Set 9 | wanlaweyn
# Processing Record 36 of Set 9 | pakxan
# Processing Record 37 of Set 9 | sukumo
# Processing Record 38 of Set 9 | ancud
# Processing Record 39 of Set 9 | araouane
# Processing Record 40 of Set 9 | sanchursk
# Processing Record 41 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 9 | kaa-khem
# Processing Record 44 of Set 9 | gravatai
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | bluefields
# Processing Record 47 of Set 9 | cairns
# Processing Record 48 of Set 9 | buturlino
# Processing Record 49 of Set 9 | mackay
# Processing Record 50 of Set 9 | west wendover
# Processing Record 1 of Set 10 | te anau
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | san clemente
# Processing Record 4 of Set 10 | koubia
# Processing Record 5 of Set 10 | lake station
# Processing Record 6 of Set 10 | presidencia roque saenz pena
# Processing Record 7 of Set 10 | katherine
# Processing Record 8 of Set 10 | alta floresta
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | nova prata
# Processing Record 11 of Set 10 | onguday
# Processing Record 12 of Set 10 | vestmannaeyjar
# Processing Record 13 of Set 10 | chimbote
# Processing Record 14 of Set 10 | warwick
# Processing Record 15 of Set 10 | husavik
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | fuling
# Processing Record 18 of Set 10 | middletown
# Processing Record 19 of Set 10 | cockburn town
# Processing Record 20 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 10 | soyaltepec
# City not found. Skipping...
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | umm lajj
# Processing Record 24 of Set 10 | vallenar
# Processing Record 25 of Set 10 | south venice
# Processing Record 26 of Set 10 | owando
# Processing Record 27 of Set 10 | dibulla
# Processing Record 28 of Set 10 | punganuru
# Processing Record 29 of Set 10 | santa cruz
# Processing Record 30 of Set 10 | iquitos
# Processing Record 31 of Set 10 | ternate
# Processing Record 32 of Set 10 | merrill
# Processing Record 33 of Set 10 | niono
# Processing Record 34 of Set 10 | teeli
# Processing Record 35 of Set 10 | canoa
# Processing Record 36 of Set 10 | nhulunbuy
# Processing Record 37 of Set 10 | bentiu
# Processing Record 38 of Set 10 | bogorodskoye
# Processing Record 39 of Set 10 | lermontovka
# Processing Record 40 of Set 10 | zhezkazgan
# Processing Record 41 of Set 10 | sistranda
# Processing Record 42 of Set 10 | luang prabang
# Processing Record 43 of Set 10 | kyabe
# Processing Record 44 of Set 10 | camalu
# Processing Record 45 of Set 10 | prado
# Processing Record 46 of Set 10 | lorengau
# Processing Record 47 of Set 10 | mbaiki
# Processing Record 48 of Set 10 | lakes entrance
# Processing Record 49 of Set 10 | raymondville
# Processing Record 50 of Set 10 | hays
# Processing Record 1 of Set 11 | borskoye
# Processing Record 2 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 11 | saint-augustin
# Processing Record 5 of Set 11 | nouadhibou
# Processing Record 6 of Set 11 | udala
# Processing Record 7 of Set 11 | bataipora
# Processing Record 8 of Set 11 | ambatondrazaka
# Processing Record 9 of Set 11 | ulladulla
# Processing Record 10 of Set 11 | huarmey
# Processing Record 11 of Set 11 | la huerta
# Processing Record 12 of Set 11 | gorahun
# Processing Record 13 of Set 11 | port-cartier
# Processing Record 14 of Set 11 | kholodnyy
# Processing Record 15 of Set 11 | panguna
# Processing Record 16 of Set 11 | ocos
# Processing Record 17 of Set 11 | tari
# Processing Record 18 of Set 11 | cayhagan
# Processing Record 19 of Set 11 | key west
# Processing Record 20 of Set 11 | belchertown
# Processing Record 21 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | bandarbeyla
# Processing Record 24 of Set 11 | henzada
# City not found. Skipping...
# Processing Record 25 of Set 11 | altukhovo
# Processing Record 26 of Set 11 | porto torres
# Processing Record 27 of Set 11 | qiyang
# Processing Record 28 of Set 11 | andilamena
# Processing Record 29 of Set 11 | pringsewu
# Processing Record 30 of Set 11 | lixourion
# Processing Record 31 of Set 11 | thaba-tseka
# Processing Record 32 of Set 11 | huilong
# Processing Record 33 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 34 of Set 11 | urusha
# Processing Record 35 of Set 11 | shasta lake
# Processing Record 36 of Set 11 | jalu
# Processing Record 37 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 11 | dakar
# Processing Record 39 of Set 11 | mejorada del campo
# Processing Record 40 of Set 11 | tucurui
# Processing Record 41 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 11 | gogrial
# Processing Record 43 of Set 11 | manali
# Processing Record 44 of Set 11 | rio tuba
# Processing Record 45 of Set 11 | jian
# Processing Record 46 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 11 | mezen
# Processing Record 48 of Set 11 | malakal
# Processing Record 49 of Set 11 | waddan
# Processing Record 50 of Set 11 | maceio
# Processing Record 1 of Set 12 | guhagar
# Processing Record 2 of Set 12 | anzhero-sudzhensk
# Processing Record 3 of Set 12 | trincomalee
# Processing Record 4 of Set 12 | sibolga
# Processing Record 5 of Set 12 | ypsonas
# Processing Record 6 of Set 12 | manzhouli
# Processing Record 7 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 12 | sharjah
# Processing Record 9 of Set 12 | tuy hoa
# Processing Record 10 of Set 12 | kearney
# Processing Record 11 of Set 12 | mahibadhoo
# Processing Record 12 of Set 12 | coari
# Processing Record 13 of Set 12 | henties bay
# Processing Record 14 of Set 12 | los andes
# Processing Record 15 of Set 12 | chernenko
# Processing Record 16 of Set 12 | am timan
# Processing Record 17 of Set 12 | alenquer
# Processing Record 18 of Set 12 | vaitape
# Processing Record 19 of Set 12 | gasa
# Processing Record 20 of Set 12 | turukhansk
# Processing Record 21 of Set 12 | namtsy
# Processing Record 22 of Set 12 | boyolangu
# Processing Record 23 of Set 12 | sobolevo
# Processing Record 24 of Set 12 | bay roberts
# Processing Record 25 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 12 | taszar
# Processing Record 27 of Set 12 | panshi
# Processing Record 28 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 12 | duma
# Processing Record 30 of Set 12 | bousso
# Processing Record 31 of Set 12 | forbes
# Processing Record 32 of Set 12 | ellensburg
# Processing Record 33 of Set 12 | xuddur
# Processing Record 34 of Set 12 | la argentina
# Processing Record 35 of Set 12 | luza
# Processing Record 36 of Set 12 | waitati
# Processing Record 37 of Set 12 | beringovskiy
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | ribeira brava
# Processing Record 40 of Set 12 | piacabucu
# Processing Record 41 of Set 12 | korla
# Processing Record 42 of Set 12 | ondangwa
# Processing Record 43 of Set 12 | kobryn
# Processing Record 44 of Set 12 | salinas
# Processing Record 45 of Set 12 | talnakh
# Processing Record 46 of Set 12 | ossora
# Processing Record 47 of Set 12 | colinas
# Processing Record 48 of Set 12 | monrovia
# Processing Record 49 of Set 12 | carros
# Processing Record 50 of Set 12 | santa maria
# Processing Record 1 of Set 13 | kayes
# Processing Record 2 of Set 13 | portales
# Processing Record 3 of Set 13 | usinsk
# Processing Record 4 of Set 13 | challapata
# Processing Record 5 of Set 13 | bosaso
# Processing Record 6 of Set 13 | sharlyk
# Processing Record 7 of Set 13 | iquique
# Processing Record 8 of Set 13 | gujar khan
# Processing Record 9 of Set 13 | bud
# Processing Record 10 of Set 13 | puerto cortes
# City not found. Skipping...
# Processing Record 11 of Set 13 | cap malheureux
# Processing Record 12 of Set 13 | moramanga
# Processing Record 13 of Set 13 | hokitika
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | muli
# Processing Record 16 of Set 13 | anan
# Processing Record 17 of Set 13 | nuuk
# Processing Record 18 of Set 13 | bhadravati
# Processing Record 19 of Set 13 | khasan
# Processing Record 20 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 21 of Set 13 | sandovo
# Processing Record 22 of Set 13 | gornopravdinsk
# Processing Record 23 of Set 13 | kalmunai
# Processing Record 24 of Set 13 | mangochi
# Processing Record 25 of Set 13 | kastamonu
# Processing Record 26 of Set 13 | ucluelet
# Processing Record 27 of Set 13 | saint anthony
# Processing Record 28 of Set 13 | herat
# Processing Record 29 of Set 13 | qasigiannguit
# Processing Record 30 of Set 13 | sal rei
# Processing Record 31 of Set 13 | atar
# Processing Record 32 of Set 13 | zhuhai
# Processing Record 33 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 13 | moron
# Processing Record 35 of Set 13 | champerico
# Processing Record 36 of Set 13 | muros
# Processing Record 37 of Set 13 | shu
# Processing Record 38 of Set 13 | san jeronimo
# Processing Record 39 of Set 13 | kiunga
# Processing Record 40 of Set 13 | mayor pablo lagerenza
# Processing Record 41 of Set 13 | ndungu
# Processing Record 42 of Set 13 | vikhorevka
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 45 of Set 13 | stabat
# Processing Record 46 of Set 13 | mazagao
# Processing Record 47 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 13 | shuyskoye
# Processing Record 49 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 13 | konevo
# Processing Record 1 of Set 14 | olinda
# Processing Record 2 of Set 14 | moose factory
# Processing Record 3 of Set 14 | payo
# Processing Record 4 of Set 14 | leshukonskoye
# Processing Record 5 of Set 14 | ust-maya
# Processing Record 6 of Set 14 | ambilobe
# Processing Record 7 of Set 14 | la palma
# Processing Record 8 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 14 | talagang
# Processing Record 10 of Set 14 | kosh-agach
# Processing Record 11 of Set 14 | mabaruma
# Processing Record 12 of Set 14 | namatanai
# Processing Record 13 of Set 14 | kaduna
# Processing Record 14 of Set 14 | mossendjo
# Processing Record 15 of Set 14 | ustrzyki dolne
# Processing Record 16 of Set 14 | thinadhoo
# Processing Record 17 of Set 14 | spilimbergo
# Processing Record 18 of Set 14 | obo
# Processing Record 19 of Set 14 | surt
# Processing Record 20 of Set 14 | saint-pierre
# Processing Record 21 of Set 14 | slave lake
# Processing Record 22 of Set 14 | sao joao da barra
# Processing Record 23 of Set 14 | kontagora
# Processing Record 24 of Set 14 | whitehorse
# Processing Record 25 of Set 14 | ransang
# Processing Record 26 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 14 | berea
# Processing Record 28 of Set 14 | cabo san lucas
# Processing Record 29 of Set 14 | san pedro de macoris
# Processing Record 30 of Set 14 | nordborg
# Processing Record 31 of Set 14 | milkovo
# Processing Record 32 of Set 14 | sosnovka
# Processing Record 33 of Set 14 | bagdarin
# Processing Record 34 of Set 14 | birobidzhan
# Processing Record 35 of Set 14 | tual
# Processing Record 36 of Set 14 | bitkine
# Processing Record 37 of Set 14 | avallon
# Processing Record 38 of Set 14 | betera
# Processing Record 39 of Set 14 | lenoir city
# Processing Record 40 of Set 14 | calabozo
# Processing Record 41 of Set 14 | clarksburg
# Processing Record 42 of Set 14 | marawi
# Processing Record 43 of Set 14 | yenagoa
# Processing Record 44 of Set 14 | port hedland
# Processing Record 45 of Set 14 | koumac
# Processing Record 46 of Set 14 | bull savanna
# Processing Record 47 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | uvat
# Processing Record 50 of Set 14 | thongwa
# Processing Record 1 of Set 15 | san quintin
# Processing Record 2 of Set 15 | kasama
# Processing Record 3 of Set 15 | maku
# Processing Record 4 of Set 15 | fare
# Processing Record 5 of Set 15 | karistos
# City not found. Skipping...
# Processing Record 6 of Set 15 | strelka
# Processing Record 7 of Set 15 | pangody
# Processing Record 8 of Set 15 | itzehoe
# Processing Record 9 of Set 15 | bandundu
# Processing Record 10 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 11 of Set 15 | pervomayskoye
# Processing Record 12 of Set 15 | mongu
# Processing Record 13 of Set 15 | sungaipenuh
# Processing Record 14 of Set 15 | suez
# Processing Record 15 of Set 15 | orlik
# Processing Record 16 of Set 15 | isla mujeres
# Processing Record 17 of Set 15 | beruwala
# Processing Record 18 of Set 15 | taos
# Processing Record 19 of Set 15 | rio gallegos
# Processing Record 20 of Set 15 | nome
# Processing Record 21 of Set 15 | naron
# Processing Record 22 of Set 15 | batagay-alyta
# Processing Record 23 of Set 15 | codrington
# Processing Record 24 of Set 15 | olga
# Processing Record 25 of Set 15 | eydhafushi
# Processing Record 26 of Set 15 | ewa beach
# Processing Record 27 of Set 15 | sao filipe
# Processing Record 28 of Set 15 | wazzan
# City not found. Skipping...
# Processing Record 29 of Set 15 | dzerzhinsk
# Processing Record 30 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 15 | sento se
# City not found. Skipping...
# Processing Record 32 of Set 15 | kailua
# Processing Record 33 of Set 15 | aguas vermelhas
# Processing Record 34 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 15 | powell river
# Processing Record 36 of Set 15 | naryan-mar
# Processing Record 37 of Set 15 | belmonte
# Processing Record 38 of Set 15 | lao cai
# Processing Record 39 of Set 15 | goudomp
# City not found. Skipping...
# Processing Record 40 of Set 15 | baiyin
# Processing Record 41 of Set 15 | syracuse
# Processing Record 42 of Set 15 | laela
# Processing Record 43 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 15 | astoria
# Processing Record 45 of Set 15 | dolinsk
# Processing Record 46 of Set 15 | hualmay
# Processing Record 47 of Set 15 | kembe
# Processing Record 48 of Set 15 | hay river
# Processing Record 49 of Set 15 | nkan
# Processing Record 50 of Set 15 | balikpapan
# Processing Record 1 of Set 16 | tooele
# Processing Record 2 of Set 16 | santa cruz cabralia
# Processing Record 3 of Set 16 | hun
# Processing Record 4 of Set 16 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 16 | pontianak
# Processing Record 6 of Set 16 | mount pleasant
# Processing Record 7 of Set 16 | aldan
# Processing Record 8 of Set 16 | cururupu
# Processing Record 9 of Set 16 | gwanda
# Processing Record 10 of Set 16 | benguela
# Processing Record 11 of Set 16 | madurai
# Processing Record 12 of Set 16 | kathmandu
# Processing Record 13 of Set 16 | noumea
# Processing Record 14 of Set 16 | tarbagatay
# Processing Record 15 of Set 16 | betsiamites
# Processing Record 16 of Set 16 | hemsedal
# Processing Record 17 of Set 16 | bonavista
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 696

# %%
len(city_data)
print(type(city_description))
# Out:
# <class 'str'>

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       San Juan      AR -31.5375  -68.5364     85.51        39          34
# 1     Georgetown      MY   5.4112  100.3354     80.89        84          20
# 2     Launceston      AU -41.4500  147.1667     51.80        74          40
# 3        Mataura      NZ -46.1927  168.8643     56.48        98         100
# 4      Mount Isa      AU -20.7333  139.5000     80.37        74          75
# ..           ...     ...      ...       ...       ...       ...         ...
# 691       Noumea      NC -22.2763  166.4572     69.78        83          86
# 692   Tarbagatay      RU  51.4803  107.3602    -13.47       100          99
# 693  Betsiamites      CA  48.9413  -68.6460     34.20        91         100
# 694     Hemsedal      NO  60.8629    8.5534     13.96        95          94
# 695    Bonavista      CA  48.6499  -53.1147     30.11        70          19
#
#      Wind Speed Current Description
# 0         18.14    scattered clouds
# 1          4.61          few clouds
# 2          3.00    scattered clouds
# 3          4.99     overcast clouds
# 4          5.75       moderate rain
# ..          ...                 ...
# 691        9.71     overcast clouds
# 692        1.66     overcast clouds
# 693       18.19     overcast clouds
# 694        3.67     overcast clouds
# 695       14.58          few clouds
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
